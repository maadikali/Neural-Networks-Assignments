# %%
from keras import models
from keras import layers
from keras.datasets import imdb
import numpy as np

# Load the IMDB dataset
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# Vectorize the sequences
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# Build the neural network
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#trainthekerasmodelonthedataset

# Train the model on the IMDb dataset
history = model.fit(x_train, y_train, epochs=10, batch_size=10, validation_split=0.2)
accuracy= model.evaluate(x_test, y_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step
# Epoch 1/10
# 2000/2000 [==============================] - 12s 5ms/step - loss: 0.3267 - accuracy: 0.8645 - val_loss: 0.2773 - val_accuracy: 0.8890
# Epoch 2/10
# 2000/2000 [==============================] - 11s 6ms/step - loss: 0.1829 - accuracy: 0.9306 - val_loss: 0.3042 - val_accuracy: 0.8804
# Epoch 3/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.1284 - accuracy: 0.9520 - val_loss: 0.3454 - val_accuracy: 0.8756
# Epoch 4/10
# 2000/2000 [==============================] - 11s 5ms/step - loss: 0.0821 - accuracy: 0.9688 - val_loss: 0.4295 - val_accuracy: 0.8740
# Epoch 5/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.0472 - accuracy: 0.9830 - val_loss: 0.5547 - val_accuracy: 0.8730
# Epoch 6/10
# 2000/2000 [==============================] - 9s 5ms/step - loss: 0.0302 - accuracy: 0.9890 - val_loss: 0.6464 - val_accuracy: 0.8686
# Epoch 7/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.0162 - accuracy: 0.9944 - val_loss: 0.8728 - val_accuracy: 0.8670
# Epoch 8/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.9318 - val_accuracy: 0.8674
# Epoch 9/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 1.0375 - val_accuracy: 0.8702
# Epoch 10/10
# 2000/2000 [==============================] - 9s 5ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.9276 - val_accuracy: 0.8690
# 782/782 [==============================] - 2s 2ms/step - loss: 1.0184 - accuracy: 0.8520

# %%
from matplotlib import pyplot as plt

#plotting train and validation accuracy

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from keras import regularizers

# Build the neural network
model = models.Sequential()
model.add(layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l1(0.01), input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#trainthekerasmodelonthedataset

# Train the model on the IMDb dataset
history = model.fit(x_train, y_train, epochs=10, batch_size=10, validation_split=0.2)
accuracy= model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 2000/2000 [==============================] - 12s 6ms/step - loss: 1.1012 - accuracy: 0.7754 - val_loss: 1.0347 - val_accuracy: 0.8036
# Epoch 2/10
# 2000/2000 [==============================] - 11s 5ms/step - loss: 0.9924 - accuracy: 0.8368 - val_loss: 0.9610 - val_accuracy: 0.8500
# Epoch 3/10
# 2000/2000 [==============================] - 11s 5ms/step - loss: 0.9547 - accuracy: 0.8435 - val_loss: 0.8896 - val_accuracy: 0.8552
# Epoch 4/10
# 2000/2000 [==============================] - 11s 5ms/step - loss: 0.9146 - accuracy: 0.8433 - val_loss: 0.8885 - val_accuracy: 0.8568
# Epoch 5/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.9065 - accuracy: 0.8467 - val_loss: 0.8893 - val_accuracy: 0.8438
# Epoch 6/10
# 2000/2000 [==============================] - 11s 6ms/step - loss: 0.9090 - accuracy: 0.8474 - val_loss: 0.8995 - val_accuracy: 0.8534
# Epoch 7/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.9014 - accuracy: 0.8503 - val_loss: 0.9474 - val_accuracy: 0.8542
# Epoch 8/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.9088 - accuracy: 0.8501 - val_loss: 0.8860 - val_accuracy: 0.8558
# Epoch 9/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.9053 - accuracy: 0.8474 - val_loss: 0.9028 - val_accuracy: 0.8460
# Epoch 10/10
# 2000/2000 [==============================] - 10s 5ms/step - loss: 0.9040 - accuracy: 0.8493 - val_loss: 0.9899 - val_accuracy: 0.8124
# 782/782 [==============================] - 3s 4ms/step - loss: 0.9982 - accuracy: 0.8059

# %%
from matplotlib import pyplot as plt

#plotting train and validation accuracy

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from matplotlib import pyplot as plt

#plotting train and validation accuracy

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
